# %% [markdown]
# <a href="https://colab.research.google.com/github/ZerocksX/SDM-SS20/blob/master/SDM_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import pandas as pd

# %%
# skin_noskin
sns_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00229/Skin_NonSkin.txt'

# %%
df = pd.read_csv(sns_url, sep='\t', header=None)
n = df.size

# %%
df_sample = df.sample(1000)
df_sample_f = df_sample[df_sample[3]==1]
df_sample_t = df_sample[df_sample[3]==2]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(df_sample_t[0], df_sample_t[1], df_sample_t[2],c='b')
ax.scatter3D(df_sample_f[0], df_sample_f[1], df_sample_f[2], c='r')

# %%
def random_initialisation(X:pd.DataFrame, k):
  return X.sample(k)

class KMeans():
  def __init__(self, X_train:pd.DataFrame, k=2, initialisation=random_initialisation):
    self.X_train = X_train
    self.centroids = initialisation(X_train, k)
  def fit(self):
    pass
  def predict(self, X_test):
    pass

# %%
kmeans = KMeans(df_sample[[0,1,2]])
kmeans.centroids
# Out:
#           0    1    2
# 145878  177  174  129
# 165612  131  134   85
